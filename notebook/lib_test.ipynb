# %%
import asyncore
import nexstarevo as nse 
reload(nse)
# Out:
# <module 'nexstarevo' from 'nexstarevo.pyc'>

# %%
scope=nse.NSEScope(addr='10.111.1.20')
asyncore.loop(count=100)
scope.close()
# Out:
# Hello!
# msg: A [4]  HC+ =>  AZM ( MC_MOVE_POS): 0x09
# msg: A [3]  AZM =>  HC+ ( MC_MOVE_POS):
# msg: A [4]  HC+ =>  AZM ( MC_MOVE_POS): 0x00
# msg: A [3]  AZM =>  HC+ ( MC_MOVE_POS):
# msg: A [4]  HC+ =>  AZM ( MC_MOVE_NEG): 0x09
# msg: A [3]  AZM =>  HC+ ( MC_MOVE_NEG):
# msg: A [4]  HC+ =>  AZM ( MC_MOVE_POS): 0x00
# msg: A [3]  AZM =>  HC+ ( MC_MOVE_POS):
# msg: A [4]  HC+ =>  ALT ( MC_MOVE_POS): 0x09
# msg: A [3]  ALT =>  HC+ ( MC_MOVE_POS):
# msg: A [4]  HC+ =>  ALT ( MC_MOVE_POS): 0x00
# msg: A [3]  ALT =>  HC+ ( MC_MOVE_POS):
# msg: A [4]  HC+ =>  ALT ( MC_MOVE_NEG): 0x09
# msg: A [3]  ALT =>  HC+ ( MC_MOVE_NEG):
# msg: A [4]  HC+ =>  ALT ( MC_MOVE_POS): 0x00
# msg: A [3]  ALT =>  HC+ ( MC_MOVE_POS):
# msg: A [3]  HC+ =>  ALT (  MC_GET_???):
# msg: A [5]  ALT =>  HC+ (  MC_GET_???): 0x16 0x85
# msg: A [3]  HC+ =>  AZM (  MC_GET_???):
# msg: A [5]  AZM =>  HC+ (  MC_GET_???): 0x16 0x85
# msg: A [3]  HC+ =>  AZM (     GET_VER):
# ...
