# %%
import asyncore
import nexstarevo as nse 
reload(nse)
# Out:
# <module 'nexstarevo' from 'nexstarevo.pyc'>

# %%
scope=nse.NSEScope(addr='10.111.1.20')
asyncore.loop(count=100)
scope.close()
# Out:
# Hello!
# msg: A [3]  HC+ =>  AZM (MC_GET_POSITION):
# msg: A [6]  AZM =>  HC+ (MC_GET_POSITION): 232°23'11.6"
# msg: A [3]  HC+ =>  ALT (MC_GET_POSITION):
# msg: A [6]  ALT =>  HC+ (MC_GET_POSITION): 032°49'21.7"
# msg: A [6]  HC+ =>  AZM (MC_SET_POS_GUIDERATE): 000°20'21.7"
# msg: A [3]  AZM =>  HC+ (MC_SET_POS_GUIDERATE):
# msg: A [6]  HC+ =>  ALT (MC_SET_NEG_GUIDERATE): 000°09'47.6"
# msg: A [3]  ALT =>  HC+ (MC_SET_NEG_GUIDERATE):
# msg: A [3]  HC+ =>  AZM (MC_GET_POSITION):
# msg: A [6]  AZM =>  HC+ (MC_GET_POSITION): 232°30'55.8"
# msg: A [3]  HC+ =>  ALT (MC_GET_POSITION):
# msg: A [6]  ALT =>  HC+ (MC_GET_POSITION): 032°45'38.7"
# msg: A [6]  HC+ =>  AZM (MC_SET_POS_GUIDERATE): 000°20'20.1"
# msg: A [3]  AZM =>  HC+ (MC_SET_POS_GUIDERATE):
# msg: A [6]  HC+ =>  ALT (MC_SET_NEG_GUIDERATE): 000°09'48.6"
# msg: A [3]  ALT =>  HC+ (MC_SET_NEG_GUIDERATE):
# msg: A [3] 0d => 10 (3b):
# msg: A [4] 10 => 0d (3b): 0x00
# msg: A [3]  HC+ =>  AZM (MC_GET_POSITION):
# ...
